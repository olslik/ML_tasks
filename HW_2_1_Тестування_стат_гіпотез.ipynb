# %% [markdown]
# В цьому ДЗ потренуємось виконувати Z-тести для тестування гіпотез в різних задачах. Для коректної імплементації та інтерпретації тестів рекоемндую переглянути спершу документацію:
#
# https://www.statsmodels.org/dev/generated/statsmodels.stats.weightstats.ztest.html
#
# ### Завдання 1: Z-тест для однієї вибірки
#
# **Мета**: Перевірити, чи середнє значення вибірки відрізняється від гіпотетичного середнього.
#
# **Припущення**: Середній ріст студентів університету вважається 170 см. Ми хочемо перевірити, чи середній ріст випадкової вибірки студентів істотно більший. Вибірка задана в змінній `heights`.
#
# Для виконання завдання імпортуйте метод для проведення `ztest`, виконайте Z-тест з Python, виведіть p-value і зробіть заключення, чи справдилось припущення про середній зріст студентів на рівні значущості 0.05?
#
# Використовуємо тут Z-тест, оскільки вибірка достатньо велика (більше 30 екземплярів) і можемо вважати, що її стандартне відхилення близьке до ст. відхилення генеральної сукупності, а значить - відоме.

# %%
heights = [174, 171, 175, 179, 170, 170, 179, 175, 169, 174, 169, 169, 173, 162, 163, 169, 166,
           173, 167, 164, 179, 170, 172, 164, 169, 175, 169, 174, 169, 169, 173, 162, 177]

# %%
from statsmodels.stats.weightstats import ztest
import numpy as np

# %% [markdown]
# **Нульова гіпотеза**: різниця між середніми оцінками двох груп студентів не є статистично значущою на рівні 0.05, тобто новий курс не є ефективнішим.
#
# **Альтернативна гіпотеза**: середня оцінка студентів з новим крусом є істотно більшою на рівні статистичної значущості 0.05, тобто новий курс є ефективнішим.

# %%
h_mean_null = 170
h_mean_sample = np.mean(heights)
print(f'Середній ріст студентів університету:\t\t {h_mean_null:.1f} см')
print(f'Середній ріст випадкової вибірки студентів:\t {h_mean_sample:.1f} см')

alpha = 0.05
ztest_Score, p_value = ztest(heights, value = h_mean_null, alternative='larger')
print('\nZ-test results:\n\ttest statistic: ', ztest_Score, '\n\tp_value: ', p_value)

if(p_value < alpha):
    print("\nВисновок.\nВідхилити Н0.")
    print(f'Тобто середній ріст нашої випадкової вибірки студентів ({h_mean_sample:.1f} см) істотно більший',
          f'ніж середній ріст студентів університету ({h_mean_null:.1f} см).')
else:
    print("\nВисновок.\nН0 не може бути відхилена.") 
    print(f'Тобто середній ріст нашої випадкової вибірки студентів ({h_mean_sample:.1f} см) не є істотно більшим',
          f'ніж середній ріст студентів університету ({h_mean_null:.1f} см).')
# Out:
# Середній ріст студентів університету:		 170.0 см
# Середній ріст випадкової вибірки студентів:	 170.7 см
#
# Z-test results:
# 	test statistic:  0.8482235371587619
# 	p_value:  0.19815674571091746
#
# Висновок.
# Н0 не може бути відхилена.
# Тобто середній ріст нашої випадкової вибірки студентів (170.7 см) не є істотно більшим ніж середній ріст студентів університету (170.0 см).

# %% [markdown]
# ### Завдання 2: Z-тест для двох незалежних вибірок
#
# **Завдання 2.1.**
#
# **Мета**: Перевірити, чи існує статистична різниця між середніми оцінками двох груп студентів.
#
# **Припущення**: Група A отримала новий навчальний курс, а група B продовжувала зі стандартним курсом. Ми перевіряємо, чи є новий курс ефективнішим.
#
# Виконайте Z-тест з Python, виведіть p-value і зробіть заключення, чи справдилось припущення щодо студентів на рівні значущості 0.05?

# %%
group_a_scores = [78.55, 72.25, 79.88, 75.  , 76.54, 74.99, 87.26, 77.93, 72.71,
       82.11, 71.9 , 79.04, 68.2 , 71.36, 78.98, 81.69, 78.86, 77.42,
       76.49, 70.61, 74.4 , 75.7 , 83.29, 79.72, 69.18, 79.62, 76.07,
       74.62, 81.06, 83.15, 82.66, 73.8 , 76.45, 79.66, 82.88, 75.6 ,
       77.07, 72.47, 72.02, 82.06]

group_b_scores = [81.78, 74.64, 80.02, 76.81, 71.77, 76.81, 82.69, 74.82, 82.82,
       61.9 , 79.11, 75.44, 73.5 , 75.46, 65.06, 73.9 , 76.79, 82.39,
       72.41, 70.96, 72.49, 79.58, 76.64, 72.35, 77.57, 75.49, 79.84,
       71.49, 73.36, 73.04, 67.68, 76.48, 76.31, 75.03, 73.83, 67.92,
       72.9 , 73.29, 70.99, 74.19]

# %% [markdown]
# **Нульова гіпотеза**: різниця між середніми оцінками двох груп студентів не є статистично значущою на рівні 0.05, тобто новий курс не є ефективнішим.
#
# **Альтернативна гіпотеза**: середня оцінка студентів з новим крусом є істотно більшою на рівні статистичної значущості 0.05, тобто новий курс є ефективнішим.

# %%
groupA_mean = np.mean(group_a_scores)
groupB_mean = np.mean(group_b_scores)
print(f'Середня оцінка студентів з новим навчальним курсом:\t\t {groupA_mean:.2f}')
print(f'Середня оцінка студентів зі стандартним навчальним курсом:\t {groupB_mean:.2f}')

alpha = 0.05
ztest_Score, p_value = ztest(group_a_scores, group_b_scores, alternative='larger')
print('\nZ-test results:\n\ttest statistic: ', ztest_Score, '\n\tp_value: ', p_value)

if(p_value < alpha):
    print("\nВисновок.\nВідхилити Н0.")
    print(f'Тобто середня оцінка студентів з новим навчальним курсом істотно більша ніж зі стандартним курсом.')
else:
    print("\nВисновок.\nН0 не може бути відхилена.") 
    print(f'Тобто середня оцінка студентів з новим навчальним курсом не є істотно більшою ніж зі стандартним курсом.')
# Out:
# Середня оцінка студентів з новим навчальним курсом:		 77.08
# Середня оцінка студентів зі стандартним навчальним курсом:	 74.74
#
# Z-test results:
# 	test statistic:  2.357354864751502
# 	p_value:  0.009202824276264003
#
# Висновок.
# Відхилити Н0.
# Тобто середня оцінка студентів з новим навчальним курсом істотно більша ніж зі стандартним курсом.

# %% [markdown]
# **Завдання 2.2.**
#
#
# **Мета**: Побачити, як впливає розмір вибірок на результат тесту.
#
# **Завдання**: Уявіть, що з групи А ми маємо тільки перші 5 записів, а з групи В - усі. Таке могло статись, якщо ми вже маємо результати тестів учнів за попередньою програмою, а тести за новою програмою здали наразі лише 5 учнів і ми вирішили не чекати довше.
# Виберіть перші 5 записів для групи А і проведіть t-test (для цього використовуємо наступний [метод](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html)). Виведіть значення p-value. Зробіть висновок, який результат ви бачите щодо стат. значущості на рівні 0.05 для цього експерименту?
#
# Тут проводимо t-test оскільки одна з вибірок - дуже мала.

# %%
group_a_scores_5 = group_a_scores[:5]
groupA5_mean = np.mean(group_a_scores_5)

print(f'Середня оцінка перших 5 студентів з новим навчальним курсом:\t {groupA5_mean:.2f}')
print(f'Середня оцінка студентів зі стандартним навчальним курсом:\t {groupB_mean:.2f}')

from scipy.stats import ttest_ind as t_test
# Out:
# Середня оцінка перших 5 студентів з новим навчальним курсом:	 76.44
# Середня оцінка студентів зі стандартним навчальним курсом:	 74.74

# %%
ttest_Score, p_value_2 = t_test(group_a_scores_5, group_b_scores, alternative='greater', equal_var=False)
print('\nT-test results:\n\ttest statistic: ', ttest_Score, '\n\tp_value: ', p_value_2)

if(p_value_2 < alpha):
    print("\nВисновок.\nВідхилити Н0.")
    print(f'Тобто середня оцінка студентів з новим навчальним курсом істотно більша ніж зі стандартним курсом.')
else:
    print("\nВисновок.\nН0 не може бути відхилена.") 
    print(f'Тобто середня оцінка студентів з новим навчальним курсом не є істотно більшою ніж зі стандартним курсом.')
# Out:
# T-test results:
# 	test statistic:  1.1226527301193456
# 	p_value:  0.1505368495172156
#
# Висновок.
# Н0 не може бути відхилена.
# Тобто середня оцінка студентів з новим навчальним курсом не є істотно більшою ніж зі стандартним курсом.

# %% [markdown]
# Таким чином, використовуючи тільки перші 5 оцінок учнів після проходження нового курсу (тобто вибірку маленького розміру), ми могли б помилково відхилити альтернативну гіпотезу, яку насправді мали прийняти (як нам відомо з висновку із попереднього завдання, де використовується більша вибірка).

# %% [markdown]
# ### Завдання 3\*: Z-тест для двох **пов'язаних** вибірок
#
# **Мета**: Перевірити, чи вплинув тренінг на продуктивність працівників, коли всі справробітники проходили тренінг.
#
# **Припущення**: Наші працівники проходять однаковий тренінг, і ми хочемо з'ясувати, чи покращилися їхні показники після тренінгу на рівні значущості 0.05. Виконайте Z-тест з Python, виведіть p-value і зробіть заключення, чи поліпшились показники працівників на рівні значущості 0.05?
#
# Зверніть увагу, ці вибірки повʼязані між собою, значить не буде коректно виконати z-test між ними, натомість, ми можемо порівняти, чи різниця в результатах (продуктивності співробітників) є стат значущою.

# %%
before_training = [57.82, 37.63, 36.8 , 55.22, 52.97, 52.5 , 53.46, 43.2 , 52.32,
       52.93, 42.86, 68.66, 54.74, 38.09, 56.57, 40.25, 57.87, 61.59,
       41.79, 59.63, 54.13, 58.22, 68.97, 47.55, 42.46, 41.1 , 41.84,
       49.23, 53.41, 52.77]

after_training = [62.47, 40.66, 42.7 , 57.69, 61.41, 56.76, 54.75, 44.06, 56.29,
       55.48, 47.28, 72.6 , 57.59, 39.39, 56.54, 42.36, 62.58, 65.01,
       42.3 , 62.98, 57.9 , 59.45, 72.28, 50.66, 43.18, 44.82, 45.96,
       54.4 , 58.52, 53.01]

# %%
# Обчислюємо різницю в результатах продуктивності співробітників

diff = []
for i in range(len(before_training)):
    diff.append(after_training[i] - before_training[i])

print(np.array(diff).round(2))
# Out:
# [ 4.65  3.03  5.9   2.47  8.44  4.26  1.29  0.86  3.97  2.55  4.42  3.94
#   2.85  1.3  -0.03  2.11  4.71  3.42  0.51  3.35  3.77  1.23  3.31  3.11
#   0.72  3.72  4.12  5.17  5.11  0.24]

# %% [markdown]
# **Нульова гіпотеза**: немає різниці між результатами до та після тренінгу, тобто тренінг не є ефективним.
#
# **Альтернативна гіпотеза**: показники працівників поліпшилися на рівні значущості 0.05, тобто тренінг є ефективним.

# %%
alpha = 0.05
ztest_Score, p_value = ztest(diff, value = 0, alternative = 'larger')
print('\nZ-test results:\n\ttest statistic: ', ztest_Score, '\n\tp_value: ', p_value)

if(p_value < alpha):
    print("\nВисновок.\nВідхилити Н0. Тобто показники продуктивності покращилися на рівні стат значущості 0.05, тренінг є ефективним.")
else:
    print("\nВисновок.\nН0 не може бути відхилена. Тобто тренінг не є ефектиним.")
# Out:
# Z-test results:
# 	test statistic:  9.13890009623916
# 	p_value:  3.1545359919175505e-20
#
# Висновок.
# Відхилити Н0. Тобто показники продуктивності покращилися на рівні стат значущості 0.05, тренінг є ефективним.
